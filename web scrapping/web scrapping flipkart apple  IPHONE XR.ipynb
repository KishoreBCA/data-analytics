# %% [markdown]
# **Import the required Modules:**

# %%
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# **See the structure of URL:**

# %%
#https://www.flipkart.com/search?q=macbook&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=macbook%7CLaptops&requestId=725f153c-36bb-478c-8f10-e54c60187a13&as-backfill=on&page=1
#https://www.flipkart.com/search?q=macbook&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=macbook%7CLaptops&requestId=725f153c-36bb-478c-8f10-e54c60187a13&as-backfill=on&page=2

# %%
base_url = 'https://www.flipkart.com/search?q=iphone+xr&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_9_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_9_na_na_na&as-pos=1&as-type=RECENT&suggestionId=iphone+xr%7CMobiles&requestId=c2c86382-c7e3-4ec6-b026-2403147c996e&as-searchtext=IPHONE%20XR'

# %% [markdown]
# **Create List for store the Data**

# %%
pd_name = []
price =[]
ratings = []
warranty = []
ratingsno = []
reviewsno = []
features = []
for i in range(1,3):
  time.sleep(3)
  req = requests.get(base_url+str(i))
  soup = BeautifulSoup(req.text,'html')

  #product name
  pdt_name = soup.findAll('div',attrs={'class':'_4rR01T'})
  [pd_name.append(i.text) for i in pdt_name]

  #price
  p = soup.findAll('div',attrs={'class':'_30jeq3 _1_WHN1'})
  [price.append(i.text) for i in p]

  #ratings
  r = soup.findAll('div',attrs={'class':'gUuXy-'})
  [ratings.append(i.span.div.text) for i in r]

  #warranty
  wl = soup.findAll('ul',attrs={'class':'_1xgFaf'})
  w = [i.findAll('li')[-1] for i in wl]
  [warranty.append(i.text) for i in w]

  #number of ratings and reviews
  a = soup.findAll('span',attrs={'class':'_2_R_DZ'})
  for i in a:
    a = i.text.split('&')
    ratingsno.append(a[0].split(" ")[0])
    reviewsno.append(a[1].split(" ")[0])

  #features
  prop = soup.findAll('ul',attrs={'class':'_1xgFaf'})
  for i in prop:
    a = i.findAll('li')[0:-2]
    b =[i.text for i in a]
    features.append(','.join(b))

# %%
print('pd_name= ',len(pd_name))
print('price = ',len(price))
print('ratings = ',len(ratings))
print('warranty = ',len(warranty))
print('ratingsno =',len(ratingsno))
print('reviewsno = ',len(reviewsno))
print('features = ',len(features))
# Out:
# pd_name=  48
# price =  48
# ratings =  48
# warranty =  48
# ratingsno = 48
# reviewsno =  48
# features =  48

# %%
data = pd.DataFrame({'Product':pd_name,
                     'Price':price,
                     'Ratings':ratings,
                     'Warranty':warranty,
                     'No of Ratings':ratingsno,
                     'No of Reviews':reviewsno,
                     'Features':features})
data
# Out:
#                                               Product    Price Ratings  \
# 0                     APPLE iPhone XR (White, 128 GB)  ₹44,999     4.6
# 1              APPLE iPhone XR ((PRODUCT)RED, 128 GB)  ₹44,999     4.6
# 2                    APPLE iPhone XR (Yellow, 128 GB)  ₹44,999     4.6
# 3                     APPLE iPhone XR (Black, 128 GB)  ₹44,999     4.6
# 4               APPLE iPhone XR ((PRODUCT)RED, 64 GB)  ₹39,999     4.6
# 5                      APPLE iPhone XR (Blue, 128 GB)  ₹44,999     4.6
# 6   Apple iPhone XR (Blue, 128 GB) (Includes EarPo...  ₹44,999     4.6
# 7   Apple iPhone XR ((PRODUCT)RED, 64 GB) (Include...  ₹39,999     4.6
# 8   Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...  ₹44,999     4.6
# 9   Apple iPhone XR (White, 128 GB) (Includes EarP...  ₹44,999     4.6
# 10                     APPLE iPhone XR (Black, 64 GB)  ₹39,999     4.6
# 11  Apple iPhone XR (Blue, 64 GB) (Includes EarPod...  ₹39,999     4.6
# 12                      APPLE iPhone XR (Blue, 64 GB)  ₹39,999     4.6
# 13  Apple iPhone XR (Yellow, 128 GB) (Includes Ear...  ₹44,999     4.6
# 14  Apple iPhone XR ((PRODUCT)RED, 256 GB) (Includ...  ₹91,900     4.6
# 15  Apple iPhone XR (Black, 64 GB) (Includes EarPo...  ₹39,999     4.6
# 16                     APPLE iPhone XR (White, 64 GB)  ₹39,999     4.6
# 17  Apple iPhone XR (Black, 128 GB) (Includes EarP...  ₹44,999     4.6
# 18  Apple iPhone XR (White, 256 GB) (Includes EarP...  ₹91,900     4.6
# 19  Apple iPhone XR (Yellow, 64 GB) (Includes EarP...  ₹39,999     4.6
# 20                    APPLE iPhone XR (Yellow, 64 GB)  ₹39,999     4.6
# 21                     APPLE iPhone XR (Coral, 64 GB)  ₹39,999     4.6
# 22  Apple iPhone XR (Black, 256 GB) (Includes EarP...  ₹91,900     4.6
# 23  Apple iPhone XR (Blue, 256 GB) (Includes EarPo...  ₹91,900     4.6
# 24                    APPLE iPhone XR (White, 128 GB)  ₹44,999     4.6
# 25                   APPLE iPhone XR (Yellow, 128 GB)  ₹44,999     4.6
# 26                    APPLE iPhone XR (Black, 128 GB)  ₹44,999     4.6
# 27              APPLE iPhone XR ((PRODUCT)RED, 64 GB)  ₹39,999     4.6
# 28                     APPLE iPhone XR (Blue, 128 GB)  ₹44,999     4.6
# 29  Apple iPhone XR (Blue, 128 GB) (Includes EarPo...  ₹44,999     4.6
# 30             APPLE iPhone XR ((PRODUCT)RED, 128 GB)  ₹44,999     4.6
# 31  Apple iPhone XR ((PRODUCT)RED, 64 GB) (Include...  ₹39,999     4.6
# 32  Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...  ₹44,999     4.6
# 33  Apple iPhone XR (White, 128 GB) (Includes EarP...  ₹44,999     4.6
# 34                     APPLE iPhone XR (Black, 64 GB)  ₹39,999     4.6
# 35  Apple iPhone XR (Blue, 64 GB) (Includes EarPod...  ₹39,999     4.6
# 36                      APPLE iPhone XR (Blue, 64 GB)  ₹39,999     4.6
# 37  Apple iPhone XR (Black, 64 GB) (Includes EarPo...  ₹39,999     4.6
# 38  Apple iPhone XR (Yellow, 128 GB) (Includes Ear...  ₹44,999     4.6
# 39  Apple iPhone XR ((PRODUCT)RED, 256 GB) (Includ...  ₹91,900     4.6
# 40                     APPLE iPhone XR (White, 64 GB)  ₹39,999     4.6
# 41  Apple iPhone XR (Black, 128 GB) (Includes EarP...  ₹44,999     4.6
# 42  Apple iPhone XR (White, 256 GB) (Includes EarP...  ₹91,900     4.6
# 43  Apple iPhone XR (Yellow, 64 GB) (Includes EarP...  ₹39,999     4.6
# 44                    APPLE iPhone XR (Yellow, 64 GB)  ₹39,999     4.6
# 45  Apple iPhone XR (Black, 256 GB) (Includes EarP...  ₹91,900     4.6
# 46                     APPLE iPhone XR (Coral, 64 GB)  ₹39,999     4.6
# 47  Apple iPhone XR (Blue, 256 GB) (Includes EarPo...  ₹91,900     4.6
#
#                     Warranty No of Ratings No of Reviews  \
# 0   Brand Warranty of 1 Year        99,657         8,546
# 1   Brand Warranty of 1 Year        99,657         8,546
# 2   Brand Warranty of 1 Year        99,657         8,546
# 3   Brand Warranty of 1 Year        99,657         8,546
# 4   Brand Warranty of 1 Year        99,657         8,546
# 5   Brand Warranty of 1 Year        99,657         8,546
# 6   Brand Warranty of 1 Year        99,657         8,546
# 7   Brand Warranty of 1 Year        99,657         8,546
# 8   Brand Warranty of 1 Year        99,657         8,546
# 9   Brand Warranty of 1 Year        99,657         8,546
# 10  Brand Warranty of 1 Year        99,657         8,546
# 11  Brand Warranty of 1 Year        99,657         8,546
# 12  Brand Warranty of 1 Year        99,657         8,546
# 13  Brand Warranty of 1 Year        99,657         8,546
# 14  Brand Warranty of 1 Year        99,657         8,546
# 15  Brand Warranty of 1 Year        99,657         8,546
# 16  Brand Warranty of 1 Year        99,657         8,546
# 17  Brand Warranty of 1 Year        99,657         8,546
# 18  Brand Warranty of 1 Year        99,657         8,546
# 19  Brand Warranty of 1 Year        99,657         8,546
# 20  Brand Warranty of 1 Year        99,657         8,546
# 21  Brand Warranty of 1 Year        99,657         8,546
# 22  Brand Warranty of 1 Year        99,657         8,546
# 23  Brand Warranty of 1 Year        99,657         8,546
# 24  Brand Warranty of 1 Year        99,657         8,546
# 25  Brand Warranty of 1 Year        99,657         8,546
# 26  Brand Warranty of 1 Year        99,657         8,546
# 27  Brand Warranty of 1 Year        99,657         8,546
# 28  Brand Warranty of 1 Year        99,657         8,546
# 29  Brand Warranty of 1 Year        99,657         8,546
# 30  Brand Warranty of 1 Year        99,657         8,546
# 31  Brand Warranty of 1 Year        99,657         8,546
# 32  Brand Warranty of 1 Year        99,657         8,546
# 33  Brand Warranty of 1 Year        99,657         8,546
# 34  Brand Warranty of 1 Year        99,657         8,546
# 35  Brand Warranty of 1 Year        99,657         8,546
# 36  Brand Warranty of 1 Year        99,657         8,546
# 37  Brand Warranty of 1 Year        99,657         8,546
# 38  Brand Warranty of 1 Year        99,657         8,546
# 39  Brand Warranty of 1 Year        99,657         8,546
# 40  Brand Warranty of 1 Year        99,657         8,546
# 41  Brand Warranty of 1 Year        99,657         8,546
# 42  Brand Warranty of 1 Year        99,657         8,546
# 43  Brand Warranty of 1 Year        99,657         8,546
# 44  Brand Warranty of 1 Year        99,657         8,546
# 45  Brand Warranty of 1 Year        99,657         8,546
# 46  Brand Warranty of 1 Year        99,657         8,546
# 47  Brand Warranty of 1 Year        99,657         8,546
#
#                                              Features
# 0   128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 1   128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 2   128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 3   128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 4   64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 5   128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 6   128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 7   64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 8   128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 9   128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 10  64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 11  64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 12  64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 13  128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 14  256 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 15  64 GB ROM,15.5 cm (6.102 inch) Display,12MP Re...
# 16  64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 17  128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 18  256 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 19  64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 20  64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 21  64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 22  256 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 23  256 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 24  128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 25  128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 26  128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 27  64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 28  128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 29  128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 30  128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 31  64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 32  128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 33  128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 34  64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 35  64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 36  64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 37  64 GB ROM,15.5 cm (6.102 inch) Display,12MP Re...
# 38  128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 39  256 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 40  64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 41  128 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 42  256 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 43  64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 44  64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 45  256 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...
# 46  64 GB ROM,15.49 cm (6.1 inch) Display,12MP Rea...
# 47  256 GB ROM,15.49 cm (6.1 inch) Display,12MP Re...

# %%
data.to_csv('C:/KISHORE BCA A 2ND\MATHAN 2ND BCA 2020-2023csv')
